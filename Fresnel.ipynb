# %%
# %run Fresnel.py
# Out:
# The Brewster angle is: 56.31
# Reflectance for external TE reflection = 0.040
# Reflectance for external TM reflection = 0.040
# Transmittance for external TE reflection = 0.960
# Transmittance for external TM reflection = 0.960

# %%
# %run iFresnel.py
# Out:
# The Brewster angle is: 33.69
# The critical angle is: 41.81
# Reflectance for internal TE reflection = 0.040
# Reflectance for internal TM reflection = 0.040
# Transmittance for internal TE reflection = 0.960
# Transmittance for internal TM reflection = 0.960

# %%
# %run Fresnel.py
# Out:
# The Brewster angle is: 56.31
# Reflectance for external TE reflection = 0.040
# Reflectance for external TM reflection = 0.040
# Transmittance for external TE reflection = 0.960
# Transmittance for external TM reflection = 0.960

# %%
# %run iFresnel.py
# Out:
# The Brewster angle is: 33.69
# The critical angle is: 41.81
# Reflectance for internal TE reflection = 0.040
# Reflectance for internal TM reflection = 0.040
# Transmittance for internal TE reflection = 0.960
# Transmittance for internal TM reflection = 0.960

# %%
# %run Fresnel.py
# Out:
# The Brewster angle is: 56.31
# Reflectance for external TE reflection = 0.040
# Reflectance for external TM reflection = 0.040
# Transmittance for external TE reflection = 0.960
# Transmittance for external TM reflection = 0.960

# %%
# %run iFresnel.py
# Out:
# The Brewster angle is: 33.69
# The critical angle is: 41.81
# Reflectance for internal TE reflection = 0.040
# Reflectance for internal TM reflection = 0.040
# Transmittance for internal TE reflection = 0.960
# Transmittance for internal TM reflection = 0.960
